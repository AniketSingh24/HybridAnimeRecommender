# %%
import pandas as pd
import numpy as np

# %%
anime_data=pd.read_csv('anime.csv')
rating_data=pd.read_csv('rating.csv')
rating_data=rating_data.rename(columns={'rating':'user_rating'})

# %%
anime_data=anime_data.merge(rating_data,on='anime_id')
anime_data = anime_data.rename(columns={'name': 'anime_title'})

# %%
anime_data.head()
# Out:
#    anime_id     anime_title                                 genre   type  \
# 0     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 1     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 2     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 3     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 4     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
#
#   episodes  rating  members  user_id  user_rating
# 0        1    9.37   200630       99            5
# 1        1    9.37   200630      152           10
# 2        1    9.37   200630      244           10
# 3        1    9.37   200630      271           10
# 4        1    9.37   200630      278           -1

# %%
anime_data["user_rating"].replace({-1:np.nan}, inplace=True)

# %%
anime_data.isnull().sum()
# Out:
# anime_id             0
# anime_title          0
# genre              110
# type                 4
# episodes             0
# rating               6
# members              0
# user_id              0
# user_rating    1476488
# dtype: int64

# %%
anime_data = anime_data.dropna(axis = 0, how ='any')

# %%
anime_data.isnull().sum()
# Out:
# anime_id       0
# anime_title    0
# genre          0
# type           0
# episodes       0
# rating         0
# members        0
# user_id        0
# user_rating    0
# dtype: int64

# %%
counts = anime_data['user_id'].value_counts()
anime_data = anime_data[anime_data['user_id'].isin(counts[counts >= 100].index)]

# %%
anime_data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [69], in <module>
# ----> 1 anime_data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
anime_data.shape
# Out:
# (4762920, 9)

# %%
anime_pivot=anime_data.pivot_table(index='anime_title',columns='user_id',values='user_rating').fillna(0)
anime_pivot.head(10)
# Out:
# user_id                                             5      7      11     \
# anime_title
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# &quot;Eiji&quot;                                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# .hack//G.U. Trilogy: Parody Mode                      0.0    0.0    0.0
# .hack//Gift                                           0.0    0.0    0.0
# .hack//Intermezzo                                     0.0    0.0    0.0
#
# user_id                                             14     17     21     \
# anime_title
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      8.0    0.0    0.0
# &quot;Eiji&quot;                                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# .hack//G.U. Trilogy: Parody Mode                      0.0    0.0    0.0
# .hack//Gift                                           0.0    0.0    0.0
# .hack//Intermezzo                                     0.0    0.0    0.0
#
# user_id                                             29     38     43     \
# anime_title
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# &quot;Eiji&quot;                                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# .hack//G.U. Trilogy: Parody Mode                      0.0    0.0    0.0
# .hack//Gift                                           0.0    0.0    0.0
# .hack//Intermezzo                                     0.0    0.0    0.0
#
# user_id                                             44     ...  73494  73495  \
# anime_title                                                ...
# &quot;0&quot;                                         0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0  ...    0.0    0.0
# &quot;Eiji&quot;                                      0.0  ...    0.0    0.0
# .hack//G.U. Returner                                  0.0  ...    0.0    0.0
# .hack//G.U. Trilogy                                   0.0  ...    0.0    0.0
# .hack//G.U. Trilogy: Parody Mode                      0.0  ...    0.0    0.0
# .hack//Gift                                           0.0  ...    0.0    0.0
# .hack//Intermezzo                                     0.0  ...    0.0    0.0
#
# user_id                                             73499  73500  73502  \
# anime_title
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0   10.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0   10.0
# &quot;Eiji&quot;                                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# .hack//G.U. Trilogy: Parody Mode                      0.0    0.0    0.0
# .hack//Gift                                           0.0    0.0    0.0
# .hack//Intermezzo                                     0.0    0.0    0.0
#
# user_id                                             73503  73504  73507  \
# anime_title
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# &quot;Eiji&quot;                                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# .hack//G.U. Trilogy: Parody Mode                      0.0    0.0    0.0
# .hack//Gift                                           0.0    0.0    0.0
# .hack//Intermezzo                                     0.0    0.0    0.0
#
# user_id                                             73510  73515
# anime_title
# &quot;0&quot;                                         0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    6.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0
# &quot;Eiji&quot;                                      0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0
# .hack//G.U. Trilogy: Parody Mode                      0.0    0.0
# .hack//Gift                                           0.0    0.0
# .hack//Intermezzo                                     0.0    0.0
#
# [10 rows x 19949 columns]

# %%
from scipy.sparse import csr_matrix

# %%
anime_matrix = csr_matrix(anime_pivot.values)
from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(anime_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index = np.random.choice(anime_pivot.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(anime_pivot.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 450

# %%
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(anime_pivot.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}:'.format(i, anime_pivot.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for Aoi Taiken:
#
# 1: Cello Hiki no Gauche (OVA), with distance of 0.25579159246474925:
# 2: Pony Metal U-GAIM Promotion Film, with distance of 0.38078117546159673:
# 3: Maroko, with distance of 0.3903207170284798:
# 4: Datenshi-tachi no Kyouen, with distance of 0.40140777227995295:
# 5: Mahjong Hishouden: Naki no Ryuu, with distance of 0.44567986561879214:

# %%
import re
def text_cleaning(text):
    text = re.sub(r'&quot;', '', text)
    text = re.sub(r'&#039;', '', text)
    text = re.sub(r'A&#039;s', '', text)
    text = re.sub(r'I&#039;', 'I\'', text)
    text = re.sub(r'&amp;', 'and', text)
    
    return text

anime_data['anime_title'] = anime_data['anime_title'].apply(text_cleaning)

# %%
 anime_pivot.index[indices.flatten()]
# Out:
# Index(['Aoi Taiken', 'Cello Hiki no Gauche (OVA)',
#        'Pony Metal U-GAIM Promotion Film', 'Maroko',
#        'Datenshi-tachi no Kyouen', 'Mahjong Hishouden: Naki no Ryuu'],
#       dtype='object', name='anime_title')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv = TfidfVectorizer(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3),
            stop_words = 'english')

# %%
anime_data['genre'] = anime_data['genre'].fillna('')
genres_str = anime_data['genre'].str.split(',').astype(str)
tfv_matrix = tfv.fit_transform(genres_str)

# %%
tfv_matrix.shape

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

# Compute the sigmoid kernel
sig = sigmoid_kernel(tfv_matrix, tfv_matrix)

# %%
indices = pd.Series(anime_data.index, index=anime_data['name']).drop_duplicates()

# %%
indices
